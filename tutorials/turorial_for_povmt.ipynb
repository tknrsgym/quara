# %%
import pickle
import time
from typing import List

import numpy as np
from tqdm import tqdm

from quara.objects.composite_system import CompositeSystem
from quara.objects.elemental_system import ElementalSystem
from quara.objects.matrix_basis import get_normalized_pauli_basis, get_pauli_basis, get_comp_basis
from quara.objects.povm import (
    Povm,
    get_x_measurement,
    get_y_measurement,
    get_z_measurement,
)
from quara.objects.qoperation import QOperation
from quara.objects.state import State, get_x0_1q,  get_x1_1q, get_y0_1q, get_y1_1q, get_z0_1q, get_z1_1q
from quara.protocol.qtomography.standard.standard_qst import StandardQst
from quara.protocol.qtomography.standard.standard_povmt import StandardPovmt
from quara.protocol.qtomography.standard.linear_estimator import LinearEstimator

# %%
# %load_ext autoreload
# %autoreload 2

# %%
def estimate(name: str,
             true_object: Povm,
             states: List[State],
             measurement_n: int,
             num_data: List[int], iterations: int, on_para_eq_constraint: bool=True):
    povmt = StandardPovmt(states, measurement_n, on_para_eq_constraint=on_para_eq_constraint)

    # generate empi dists and calc estimate
    obj_sequences = []
    start = time.time()
    for iteration in range(iterations):
        seeds = [iteration] * len(num_data)
        empi_dists_seq = povmt.generate_empi_dists_sequence(
            true_object, num_data, seeds
        )

        estimator = LinearEstimator()
        obj_sequence = estimator.calc_estimate_sequence(povmt, empi_dists_seq)

        info = {
            "iteration": iteration,
            "empi_dists_seq": empi_dists_seq,
            "obj_sequence": obj_sequence.estimated_var_sequence,
        }
        print(info)
        obj_sequences.append(obj_sequence.estimated_qoperation_sequence)

    end = time.time()
    print(f"time(s)={end - start}")
    #with open(f"state_obj_sequences_{name}_{on_para_eq_constraint}_{iterations}.pkl", "wb") as f:
    #    pickle.dump(obj_sequences, f)

    #with open("obj_sequences.pkl", "rb") as f:
    #    obj_sequences = pickle.load(f)
    return obj_sequences

# %%
# setup system
e_sys = ElementalSystem(0, get_normalized_pauli_basis())
c_sys = CompositeSystem([e_sys])

# |+><+|
state_x0 = get_x0_1q(c_sys)
# |+i><+i|
state_y0 = get_y0_1q(c_sys)
# |0><0|
state_z0 = get_z0_1q(c_sys)
# |1><1|
state_z1 = get_z1_1q(c_sys)
states = [state_x0, state_y0, state_z0, state_z1]

# %%
# parameter
num_data = [100, 1000, 10000, 100000]
iterations = 10
true_object = get_x_measurement(c_sys)  # TODO: 真値で置き換える
measurement_n = 2  # 測定値の数

param_affine_est_linear = estimate("name", true_object, states, measurement_n, num_data, iterations, on_para_eq_constraint=True)
param_linear_est_linear = estimate("name", true_object, states, measurement_n, num_data, iterations, on_para_eq_constraint=False)
# Out:
# {'iteration': 0, 'empi_dists_seq': [[(100, array([1., 0.])), (100, array([0.51, 0.49])), (100, array([0.51, 0.49])), (100, array([0.51, 0.49]))], [(1000, array([1., 0.])), (1000, array([0.517, 0.483])), (1000, array([0.517, 0.483])), (1000, array([0.517, 0.483]))], [(10000, array([1., 0.])), (10000, array([0.5064, 0.4936])), (10000, array([0.5064, 0.4936])), (10000, array([0.5064, 0.4936]))], [(100000, array([1., 0.])), (100000, array([0.50055, 0.49945])), (100000, array([0.50055, 0.49945])), (100000, array([0.50055, 0.49945]))]], 'obj_sequence': [array([7.21248917e-01, 6.92964646e-01, 7.77156117e-16, 0.00000000e+00]), array([7.31148412e-01, 6.83065151e-01, 8.32667268e-16, 0.00000000e+00]), array([7.16157748e-01, 6.98055814e-01, 7.77156117e-16, 0.00000000e+00]), array([7.07884599e-01, 7.06328964e-01, 7.77156117e-16, 0.00000000e+00])]}
# {'iteration': 1, 'empi_dists_seq': [[(100, array([1., 0.])), (100, array([0.51, 0.49])), (100, array([0.51, 0.49])), (100, array([0.51, 0.
-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.05692568e-01,  7.08520995e-01, -3.33066907e-16,  0.00000000e+00,
#         7.08520995e-01, -7.08520995e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.07304771e-01,  7.06908791e-01, -3.33066907e-16,  0.00000000e+00,
#         7.06908791e-01, -7.06908791e-01, -3.33066907e-16,  0.00000000e+00])]}
# {'iteration': 2, 'empi_dists_seq': [[(100, array([1., 0.])), (100, array([0.56, 0.44])), (100, array([0.56, 0.44])), (100, array([0.56, 0.44]))], [(1000, array([1., 0.])), (1000, array([0.534, 0.466])), (1000, array([0.534, 0.466])), (1000, array([0.534, 0.466]))], [(10000, array([1., 0.])), (10000, array([0.5132, 0.4868])), (10000, array([0.5132, 0.4868])), (10000, array([0.5132, 0.4868]))], [(100000, array([1., 0.])), (100000, array([0.50094, 0.49906])), (100000, array([0.50094, 0.49906])), (100000, array([0.50094, 0.49906]))]], 'obj_sequence': [array([ 7.91959595e-01,  6.22253967e-01, -4.44089210e-16,  0.00000000e+00,
#         6.22253967e-01, -6.22253967e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.55190042e-01,  6.59023520e-01, -3.33066907e-16,  0.00000000e+00,
#         6.59023520e-01, -6.59023520e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.25774400e-01,  6.88439162e-01, -3.33066907e-16,  0.00000000e+00,
#         6.88439162e-01, -6.88439162e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.08436142e-01,  7.05777420e-01, -3.33066907e-16,  0.00000000e+00,
#         7.05777420e-01, -7.05777420e-01, -3.33066907e-16,  0.00000000e+00])]}
# {'iteration': 3, 'empi_dists_seq': [[(100, array([1., 0.])), (100, array([0.53, 0.47])), (100, array([0.53, 0.47])), (100, array([0.53, 0.47]))], [(1000, array([1., 0.])), (1000, array([0.488, 0.512])), (1000, array([0.488, 0.512])), (1000, array([0.488, 0.512]))], [(10000, array([1., 0.])), (10000, array([0.5063, 0.4937])), (10000, array([0.5063, 0.4937])), (10000, array([0.5063, 0.4937]))], [(100000, array([1., 0.])), (100000, array([0.49959, 0.50041])), (100000, array([0.49959, 0.50041])), (100000, array([0.49959, 0.50041]))]], 'obj_sequence': [array([ 7.49533188e-01,  6.64680374e-01, -3.33066907e-16,  0.00000000e+00,
#         6.64680374e-01, -6.64680374e-01, -3.33066907e-16,  0.00000000e+00]), array([ 6.90136218e-01,  7.24077344e-01, -3.33066907e-16,  0.00000000e+00,
#         7.24077344e-01, -7.24077344e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.16016327e-01,  6.98197236e-01, -3.33066907e-16,  0.00000000e+00,
#         6.98197236e-01, -6.98197236e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.06526954e-01,  7.07686609e-01, -3.33066907e-16,  0.00000000e+00,
#         7.07686609e-01, -7.07686609e-01, -3.33066907e-16,  0.00000000e+00])]}
# {'iteration': 4, 'empi_dists_seq': [[(100, array([1., 0.])), (100, array([0.44, 0.56])), (100, array([0.44, 0.56])), (100, array([0.44, 0.56]))], [(1000, array([1., 0.])), (1000, array([0.481, 0.519])), (1000, array([0.481, 0.519])), (1000, array([0.481, 0.519]))], [(10000, array([1., 0.])), (10000, array([0.4974, 0.5026])), (10000, array([0.4974, 0.5026])), (10000, array([0.4974, 0.5026]))], [(100000, array([1., 0.])), (100000, array([0.50057, 0.49943])), (100000, array([0.50057, 0.49943])), (100000, array([0.50057, 0.49943]))]], 'obj_sequence': [array([ 6.22253967e-01,  7.91959595e-01, -3.33066907e-16,  0.00000000e+00,
#         7.91959595e-01, -7.91959595e-01, -4.44089210e-16,  0.00000000e+00]), array([ 6.80236724e-01,  7.33976839e-01, -3.33066907e-16,  0.00000000e+00,
#         7.33976839e-01, -7.33976839e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.03429826e-01,  7.10783736e-01, -3.33066907e-16,  0.00000000e+00,
#         7.10783736e-01, -7.10783736e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.07912883e-01,  7.06300679e-01, -3.33066907e-16,  0.00000000e+00,
#         7.06300679e-01, -7.06300679e-01, -3.33066907e-16,  0.00000000e+00])]}
# {'iteration': 5, 'empi_dists_seq': [[(100, array([1., 0.])), (100, array([0.51, 0.49])), (100, array([0.51, 0.49])), (100, array([0.51, 0.49]))], [(1000, array([1., 0.])), (1000, array([0.502, 0.498])), (1000, array([0.502, 0.498])), (1000, array([0.502, 0.498]))], [(10000, array([1., 0.])), (10000, array([0.4996, 0.5004])), (10000, array([0.4996, 0.5004])), (10000, array([0.4996, 0.5004]))], [(100000, array([1., 0.])), (100000, array([0.49885, 0.50115])), (100000, array([0.49885, 0.50115])), (100000, array([0.49885, 0.50115]))]], 'obj_sequence': [array([ 7.21248917e-01,  6.92964646e-01, -3.33066907e-16,  0.00000000e+00,
#         6.92964646e-01, -6.92964646e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.09935208e-01,  7.04278354e-01, -3.33066907e-16,  0.00000000e+00,
#         7.04278354e-01, -7.04278354e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.06541096e-01,  7.07672467e-01, -3.33066907e-16,  0.00000000e+00,
#         7.07672467e-01, -7.07672467e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.05480436e-01,  7.08733127e-01, -3.33066907e-16,  0.00000000e+00,
#         7.08733127e-01, -7.08733127e-01, -3.33066907e-16,  0.00000000e+00])]}
# {'iteration': 6, 'empi_dists_seq': [[(100, array([1., 0.])), (100, array([0.45, 0.55])), (100, array([0.45, 0.55])), (100, array([0.45, 0.55]))], [(1000, array([1., 0.])), (1000, array([0.497, 0.503])), (1000, array([0.497, 0.503])), (1000, array([0.497, 0.503]))], [(10000, array([1., 0.])), (10000, array([0.4916, 0.5084])), (10000, array([0.4916, 0.5084])), (10000, array([0.4916, 0.5084]))], [(100000, array([1., 0.])), (100000, array([0.50248, 0.49752])), (100000, array([0.50248, 0.49752])), (100000, array([0.50248, 0.49752]))]], 'obj_sequence': [array([ 6.36396103e-01,  7.77817459e-01, -3.33066907e-16,  0.00000000e+00,
#         7.77817459e-01, -7.77817459e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.02864140e-01,  7.11349422e-01, -3.33066907e-16,  0.00000000e+00,
#         7.11349422e-01, -7.11349422e-01, -3.33066907e-16,  0.00000000e+00]), array([ 6.95227387e-01,  7.18986175e-01, -3.33066907e-16,  0.00000000e+00,
#         7.18986175e-01, -7.18986175e-01, -4.44089210e-16,  0.00000000e+00]), array([ 7.10614031e-01,  7.03599532e-01, -3.33066907e-16,  0.00000000e+00,
#         7.03599532e-01, -7.03599532e-01, -3.33066907e-16,  0.00000000e+00])]}
# {'iteration': 7, 'empi_dists_seq': [[(100, array([1., 0.])), (100, array([0.52, 0.48])), (100, array([0.52, 0.48])), (100, array([0.52, 0.48]))], [(1000, array([1., 0.])), (1000, array([0.512, 0.488])), (1000, array([0.512, 0.488])), (1000, array([0.512, 0.488]))], [(10000, array([1., 0.])), (10000, array([0.5043, 0.4957])), (10000, array([0.5043, 0.4957])), (10000, array([0.5043, 0.4957]))], [(100000, array([1., 0.])), (100000, array([0.50031, 0.49969])), (100000, array([0.50031, 0.49969])), (100000, array([0.50031, 0.49969]))]], 'obj_sequence': [array([ 7.35391052e-01,  6.78822510e-01, -3.33066907e-16,  0.00000000e+00,
#         6.78822510e-01, -6.78822510e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.24077344e-01,  6.90136218e-01, -3.33066907e-16,  0.00000000e+00,
#         6.90136218e-01, -6.90136218e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.13187900e-01,  7.01025663e-01, -3.33066907e-16,  0.00000000e+00,
#         7.01025663e-01, -7.01025663e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.07545187e-01,  7.06668375e-01, -3.33066907e-16,  0.00000000e+00,
#         7.06668375e-01, -7.06668375e-01, -3.33066907e-16,  0.00000000e+00])]}
# {'iteration': 8, 'empi_dists_seq': [[(100, array([1., 0.])), (100, array([0.48, 0.52])), (100, array([0.48, 0.52])), (100, array([0.48, 0.52]))], [(1000, array([1., 0.])), (1000, array([0.49, 0.51])), (1000, array([0.49, 0.51])), (1000, array([0.49, 0.51]))], [(10000, array([1., 0.])), (10000, array([0.5034, 0.4966])), (10000, array([0.5034, 0.4966])), (10000, array([0.5034, 0.4966]))], [(100000, array([1., 0.])), (100000, array([0.50337, 0.49663])), (100000, array([0.50337, 0.49663])), (100000, array([0.50337, 0.49663]))]], 'obj_sequence': [array([ 6.78822510e-01,  7.35391052e-01, -3.33066907e-16,  0.00000000e+00,
#         7.35391052e-01, -7.35391052e-01, -3.33066907e-16,  0.00000000e+00]), array([ 6.92964646e-01,  7.21248917e-01, -3.33066907e-16,  0.00000000e+00,
#         7.21248917e-01, -7.21248917e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.11915107e-01,  7.02298455e-01, -3.33066907e-16,  0.00000000e+00,
#         7.02298455e-01, -7.02298455e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.11872681e-01,  7.02340881e-01, -3.33066907e-16,  0.00000000e+00,
#         7.02340881e-01, -7.02340881e-01, -3.33066907e-16,  0.00000000e+00])]}
# {'iteration': 9, 'empi_dists_seq': [[(100, array([1., 0.])), (100, array([0.56, 0.44])), (100, array([0.56, 0.44])), (100, array([0.56, 0.44]))], [(1000, array([1., 0.])), (1000, array([0.49, 0.51])), (1000, array([0.49, 0.51])), (1000, array([0.49, 0.51]))], [(10000, array([1., 0.])), (10000, array([0.5022, 0.4978])), (10000, array([0.5022, 0.4978])), (10000, array([0.5022, 0.4978]))], [(100000, array([1., 0.])), (100000, array([0.50141, 0.49859])), (100000, array([0.50141, 0.49859])), (100000, array([0.50141, 0.49859]))]], 'obj_sequence': [array([ 7.91959595e-01,  6.22253967e-01, -4.44089210e-16,  0.00000000e+00,
#         6.22253967e-01, -6.22253967e-01, -3.33066907e-16,  0.00000000e+00]), array([ 6.92964646e-01,  7.21248917e-01, -3.33066907e-16,  0.00000000e+00,
#         7.21248917e-01, -7.21248917e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.10218051e-01,  7.03995511e-01, -3.33066907e-16,  0.00000000e+00,
#         7.03995511e-01, -7.03995511e-01, -3.33066907e-16,  0.00000000e+00]), array([ 7.09100822e-01,  7.05112740e-01, -3.33066907e-16,  0.00000000e+00,
#         7.05112740e-01, -7.05112740e-01, -3.33066907e-16,  0.00000000e+00])]}
# time(s)=11.460986137390137
